# %%
# pip install dynamask

# %%
import pandas as pd

# %%
df_hdv = pd.read_csv('data/fintech_data/Xtrain/HDV.csv', index_col='Unnamed: 0')
df_hdv
# Out:
#             Date  Adj Close       SMA       EMA       ROC       RSI  \
# 0     2011-05-13  35.254963  0.326460  0.325153 -1.792271 -1.371631
# 1     2011-05-16  35.208591  0.283418  0.308570 -1.846946 -2.014872
# 2     2011-05-17  35.241718  0.220180  0.293820 -2.727310 -1.705987
# 3     2011-05-18  35.427120  0.172833  0.293865 -5.395879 -0.034861
# 4     2011-05-19  35.513203  0.183760  0.296263 -3.400910  0.688907
# ...          ...        ...       ...       ...       ...       ...
# 1665  2017-12-22  74.751663  0.706777  0.656689 -3.740096  4.090884
# 1666  2017-12-26  74.735069  0.630177  0.637183 -4.448342  3.890043
# 1667  2017-12-27  74.793144  0.566352  0.616739 -3.726470  4.126101
# 1668  2017-12-28  74.900948  0.523949  0.600259 -3.528251  4.577995
# 1669  2017-12-29  74.759949  0.538222  0.565458 -4.230720  2.521599
#
#       Predicted Close  TIC
# 0           35.811270  HDV
# 1           35.776198  HDV
# 2           35.795436  HDV
# 3           35.925255  HDV
# 4           36.016690  HDV
# ...               ...  ...
# 1665        75.202924  HDV
# 1666        75.183403  HDV
# 1667        75.243899  HDV
# 1668        75.345282  HDV
# 1669        75.235484  HDV
#
# [1670 rows x 8 columns]

# %%
df_hdv.ROC.plot()
# Out:
# <AxesSubplot:>

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

plot_acf(df_hdv.ROC)
plt.show()

# %%
import torch
from dynamask.attribution.perturbation import Perturbation
from dynamask.attribution.mask_group import MaskGroup
from dynamask.utils.losses import mse
from dynamask.attribution.perturbation import GaussianBlur
